# %%
import sqlalchemy as db
from sqlalchemy import create_engine

# %%
engine = db.create_engine('sqlite:///C:\\Users\\peter\\Documents\\Projekte\\Zähler\\tc_sg.db')

# %%
conn = engine.connect()

# %%
import pandas as pd

# %%
pd.options.display.max_rows=2000

# %%
pd.options.display.max_columns
# Out:
# 20

# %% [markdown]
# ### Abfrage 1 - Anzahl Datenpunkte

# %%
query ='''
SELECT  *, strftime('%Y', time, 'localtime') as Year, strftime('%m', time, 'localtime') as Month, strftime('%d', time, 'localtime') as Day, COUNT(time) as Anzahl
FROM tcdata_CH_0084_01
GROUP BY Year, Month
 '''

# %%
df = pd.read_sql_query(query, conn)

# %%
df.head(10)
# Out:
#                         time   vfr11        s12  vfr21   s22  vfr1   s2  Year  \
# 0  2021-06-19 05:53:00+02:00   360.0  81.800003    0.0   0.0   0.0  0.0  2021
# 1  2021-07-01 00:03:00+02:00   120.0  80.000000    0.0   0.0   0.0  0.0  2021
# 2  2021-08-01 00:00:00+02:00   480.0  68.599998    0.0   0.0   0.0  0.0  2021
# 3  2021-09-01 06:03:00+02:00  1260.0  69.800003   60.0  69.0   0.0  0.0  2021
# 4  2021-10-01 05:59:00+02:00   960.0  72.900002    0.0   0.0   0.0  0.0  2021
# 5  2021-11-01 04:59:00+01:00   240.0  68.500000    0.0   0.0   0.0  0.0  2021
# 6  2021-12-02 04:59:00+01:00   120.0  62.000000    0.0   0.0   0.0  0.0  2021
# 7  2022-01-01 04:59:00+01:00   180.0  66.000000    0.0   0.0   0.0  0.0  2022
# 8  2022-02-01 04:59:00+01:00   360.0  65.500000   60.0  72.0   0.0  0.0  2022
# 9  2022-03-01 04:59:00+01:00     0.0   0.000000    0.0   0.0   0.0  0.0  2022
#
#   Month Day  Anzahl
# 0    06  19   10087
# 1    07  01   26097
# 2    08  01    4347
# 3    09  01    4307
# 4    10  01    4143
# 5    11  01    4108
# 6    12  02    4048
# 7    01  01    4379
# 8    02  01    4059
# 9    03  01    2336

# %% [markdown]
# ### Abfrage 2 - Anzahl Datenpunkte mit Verkehrfluss vfr11

# %%
query ='''
SELECT  strftime('%Y', time, 'localtime') as Year, strftime('%m', time, 'localtime') as Month, strftime('%d', time, 'localtime') as Day, COUNT(time) as Anzahl
FROM tcdata_CH_0084_01
WHERE vfr11 > 0
GROUP BY Year, Month
 '''

# %%
df = pd.read_sql_query(query, conn)

# %%
df.head(10)
# Out:
#    Year Month Day  Anzahl
# 0  2021    06  19    9696
# 1  2021    07  01   25078
# 2  2021    08  01    4282
# 3  2021    09  01    4183
# 4  2021    10  01    4133
# 5  2021    11  01    4099
# 6  2021    12  02    4037
# 7  2022    01  01    4345
# 8  2022    02  01    3751
# 9  2022    03  01    2332

# %%
query ='''
SELECT  strftime('%Y', time, 'localtime') as Year, strftime('%m', time, 'localtime') as Month, strftime('%d', time, 'localtime') as Day, COUNT(time) as Anzahl
FROM tcdata_CH_0084_01
WHERE vfr11 IS NULL
GROUP BY Year, Month
 '''

# %%
df = pd.read_sql_query(query, conn)

# %%
df.head(10)
# Out:
#    Year Month Day  Anzahl
# 0  2022    02  14      34

# %%
query ='''
SELECT  strftime('%Y', time, 'localtime') as Year, strftime('%m', time, 'localtime') as Month, strftime('%d', time, 'localtime') as Day, COUNT(time) as Anzahl
FROM tcdata_CH_0084_01
WHERE vfr11 = 0
GROUP BY Year, Month
 '''

# %%
df = pd.read_sql_query(query, conn)

# %%
df.head(10)
# Out:
#    Year Month Day  Anzahl
# 0  2021    06  20     391
# 1  2021    07  01    1019
# 2  2021    08  01      65
# 3  2021    09  11     124
# 4  2021    10  18      10
# 5  2021    11  07       9
# 6  2021    12  08      11
# 7  2022    01  01      34
# 8  2022    02  11     274
# 9  2022    03  01       4

# %% [markdown]
# ### Abfrage 3 - Anzahl Datenpunkte mit Verkehrfluss vfr21

# %%
query ='''
SELECT  strftime('%Y', time, 'localtime') as Year, strftime('%m', time, 'localtime') as Month, strftime('%d', time, 'localtime') as Day, COUNT(time) as Anzahl
FROM tcdata_CH_0084_01
WHERE vfr21 > 0
GROUP BY Year, Month
 '''

# %%
df = pd.read_sql_query(query, conn)

# %%
df.head(10)
# Out:
#    Year Month Day  Anzahl
# 0  2021    06  19    6196
# 1  2021    07  01   15175
# 2  2021    08  01    2666
# 3  2021    09  01    2855
# 4  2021    10  01    2674
# 5  2021    11  01    2896
# 6  2021    12  02    2327
# 7  2022    01  01    2550
# 8  2022    02  01    2417
# 9  2022    03  01    1591

# %%
query ='''
SELECT  strftime('%Y', time, 'localtime') as Year, strftime('%m', time, 'localtime') as Month, strftime('%d', time, 'localtime') as Day, COUNT(time) as Anzahl
FROM tcdata_CH_0084_01
WHERE vfr21 IS NULL
GROUP BY Year, Month
 '''

# %%
df = pd.read_sql_query(query, conn)

# %%
df.head(10)
# Out:
#    Year Month Day  Anzahl
# 0  2022    02  14      34

# %%
query ='''
SELECT  strftime('%Y', time, 'localtime') as Year, strftime('%m', time, 'localtime') as Month, strftime('%d', time, 'localtime') as Day, COUNT(time) as Anzahl
FROM tcdata_CH_0084_01
WHERE vfr21 = 0
GROUP BY Year, Month
 '''

# %%
df = pd.read_sql_query(query, conn)

# %%
df.head(10)
# Out:
#    Year Month Day  Anzahl
# 0  2021    06  19    3891
# 1  2021    07  01   10922
# 2  2021    08  01    1681
# 3  2021    09  01    1452
# 4  2021    10  01    1469
# 5  2021    11  01    1212
# 6  2021    12  02    1721
# 7  2022    01  01    1829
# 8  2022    02  01    1608
# 9  2022    03  01     745

# %% [markdown]
# ### Abfrage 4 - Anzahl Datenpunkte mit Verkehrfluss vfr1

# %%
query ='''
SELECT  strftime('%Y', time, 'localtime') as Year, strftime('%m', time, 'localtime') as Month, strftime('%d', time, 'localtime') as Day, COUNT(time) as Anzahl
FROM tcdata_CH_0084_01
WHERE vfr1 > 0
GROUP BY Year, Month
 '''

# %%
df = pd.read_sql_query(query, conn)

# %%
df.head(10)
# Out:
# Empty DataFrame
# Columns: [Year, Month, Day, Anzahl]
# Index: []

# %%
query ='''
SELECT  strftime('%Y', time, 'localtime') as Year, strftime('%m', time, 'localtime') as Month, strftime('%d', time, 'localtime') as Day, COUNT(time) as Anzahl
FROM tcdata_CH_0084_01
WHERE vfr1 IS NULL
GROUP BY Year, Month
 '''

# %%
df = pd.read_sql_query(query, conn)

# %%
df.head(10)
# Out:
#    Year Month Day  Anzahl
# 0  2022    02  14      34

# %%
query ='''
SELECT  strftime('%Y', time, 'localtime') as Year, strftime('%m', time, 'localtime') as Month, strftime('%d', time, 'localtime') as Day, COUNT(time) as Anzahl
FROM tcdata_CH_0084_01
WHERE vfr1 = 0
GROUP BY Year, Month
 '''

# %%
df = pd.read_sql_query(query, conn)

# %%
df.head(10)
# Out:
#    Year Month Day  Anzahl
# 0  2021    06  19   10087
# 1  2021    07  01   26097
# 2  2021    08  01    4347
# 3  2021    09  01    4307
# 4  2021    10  01    4143
# 5  2021    11  01    4108
# 6  2021    12  02    4048
# 7  2022    01  01    4379
# 8  2022    02  01    4025
# 9  2022    03  01    2336

# %% [markdown]
# ### Dh es gibt für diesen Fahrzeugtyp keine Daten von "anderen Fahrzeugen"

# %% [markdown]
# ### Nun zu statistischen Werten (zunächst mit 0 und NULL)

# %%
query ='''
SELECT  strftime('%Y', time, 'localtime') as Year, strftime('%m', time, 'localtime') as Month, strftime('%d', time, 'localtime') as Day, COUNT(time) as Anzahl,
       ROUND(AVG(vfr11), 1) AS MEAN_Flow,
       MAX(vfr11) AS MAX_FLOW,
       MIN(vfr11) AS MIN_FLOW,
       ROUND(AVG(s12), 1) AS MEAN_Speed,
       MAX(s12) AS MAX_Speed,
       MIN(s12) AS MIN_Speed   
FROM tcdata_CH_0084_01
GROUP BY Year, Month
 '''

# %%
df = pd.read_sql_query(query, conn)

# %%
df.head(10)
# Out:
#    Year Month Day  Anzahl  MEAN_Flow  MAX_FLOW  MIN_FLOW  MEAN_Speed  \
# 0  2021    06  20   10087     1251.8    2700.0       0.0        71.6
# 1  2021    07  01   26097     1254.4    2880.0       0.0        66.7
# 2  2021    08  01    4347     1439.8    2880.0       0.0        62.3
# 3  2021    09  11    4307     1508.9    2940.0       0.0        60.2
# 4  2021    10  18    4143     1526.0    2820.0       0.0        62.3
# 5  2021    11  07    4108     1384.6    2940.0       0.0        63.6
# 6  2021    12  08    4048     1313.6    2760.0       0.0        64.1
# 7  2022    01  01    4379     1277.6    2820.0       0.0        65.4
# 8  2022    02  11    4059     1288.6    3000.0       0.0        60.4
# 9  2022    03  01    2336     1389.7    2820.0       0.0        61.7
#
#    MAX_Speed  MIN_Speed
# 0      105.0        0.0
# 1      106.0        0.0
# 2       96.0        0.0
# 3      103.0        0.0
# 4      100.0        0.0
# 5      117.0        0.0
# 6       89.0       -1.0
# 7      133.0        0.0
# 8       97.0        0.0
# 9       99.0        0.0

# %% [markdown]
# ### ...dann bereinigt!

# %%
query ='''
SELECT  strftime('%Y', time, 'localtime') as Year, strftime('%m', time, 'localtime') as Month, strftime('%d', time, 'localtime') as Day, COUNT(time) as Anzahl,
       ROUND(AVG(vfr11), 1) AS MEAN_Flow,
       MAX(vfr11) AS MAX_FLOW,
       MIN(vfr11) AS MIN_FLOW,
       ROUND(AVG(s12), 1) AS MEAN_Speed,
       MAX(s12) AS MAX_Speed,
       MIN(s12) AS MIN_Speed   
FROM tcdata_CH_0084_01
WHERE vfr11 > 0
GROUP BY Year, Month
 '''

# %%
df = pd.read_sql_query(query, conn)

# %%
df.head(10)
# Out:
#    Year Month Day  Anzahl  MEAN_Flow  MAX_FLOW  MIN_FLOW  MEAN_Speed  \
# 0  2021    06  24    9696     1302.3    2700.0      60.0        74.5
# 1  2021    07  16   25078     1305.4    2880.0      60.0        69.4
# 2  2021    08  20    4282     1461.6    2880.0      60.0        63.3
# 3  2021    09  03    4183     1553.7    2940.0      60.0        62.0
# 4  2021    10  25    4133     1529.7    2820.0      60.0        62.4
# 5  2021    11  29    4099     1387.6    2940.0      60.0        63.7
# 6  2021    12  08    4037     1317.2    2760.0      60.0        64.3
# 7  2022    01  19    4345     1287.6    2820.0      60.0        65.9
# 8  2022    02  03    3751     1382.8    3000.0      60.0        64.8
# 9  2022    03  15    2332     1392.1    2820.0      60.0        61.8
#
#    MAX_Speed  MIN_Speed
# 0      105.0       12.5
# 1      106.0       11.6
# 2       96.0       11.2
# 3      103.0        6.8
# 4      100.0       11.7
# 5      117.0        3.6
# 6       89.0       -1.0
# 7      133.0        3.0
# 8       97.0        5.0
# 9       99.0        6.1

# %% [markdown]
# ### Weitere Detaillierung nach Tag

# %%
query ='''
SELECT  strftime('%Y', time, 'localtime') as Year, strftime('%m', time, 'localtime') as Month, strftime('%d', time, 'localtime') as Day, COUNT(time) as Anzahl,
       ROUND(AVG(vfr11), 1) AS MEAN_Flow,
       MAX(vfr11) AS MAX_FLOW,
       MIN(vfr11) AS MIN_FLOW,
       ROUND(AVG(s12), 1) AS MEAN_Speed,
       MAX(s12) AS MAX_Speed,
       MIN(s12) AS MIN_Speed   
FROM tcdata_CH_0084_01
WHERE vfr11 > 0
GROUP BY Year, Month, Day
 '''

# %%
df = pd.read_sql_query(query, conn)

# %%
df.head(1000)
# Out:
#      Year Month Day  Anzahl  MEAN_Flow  MAX_FLOW  MIN_FLOW  MEAN_Speed  \
# 0    2021    06  19     781     1338.2    2220.0     120.0        76.5
# 1    2021    06  20     847      983.3    2040.0      60.0        78.6
# 2    2021    06  21     830     1324.7    2400.0      60.0        74.7
# 3    2021    06  22     839     1329.0    2340.0      60.0        74.2
# 4    2021    06  23     844     1347.9    2460.0      60.0        73.4
# 5    2021    06  24     792     1343.6    2340.0      60.0        70.7
# 6    2021    06  25     803     1402.9    2460.0      60.0        71.9
# 198   82.400002  57.599998
# 199   78.300003  56.200001
# 200   90.699997  54.599998
# 201   89.000000  48.799999
# 202   73.199997  28.700001
# 203   76.900002  41.599998
# 204   76.300003  50.799999
# 205   80.400002  52.700001
# 206   80.500000  52.400002
# 207  101.000000  56.900002
# 208   78.000000  50.000000
# 209   74.000000  44.000000
# 210   78.699997  51.900002
# 211   75.800003   3.000000
# 212   76.199997  35.200001
# 213   87.000000  47.099998
# 214   79.300003  56.299999
# 215   77.300003  58.000000
# 216   75.099998  53.799999
# 217   75.000000  36.900002
# 218   74.699997  44.900002
# 219   77.699997  31.500000
# 220   81.300003  59.700001
# 221  133.000000  57.799999
# 222   76.500000  50.299999
# 223   97.000000  48.299999
# 224   84.000000  37.500000
# 225   75.300003   5.000000
# 226   83.099998  33.799999
# 227   80.400002  56.500000
# 228   86.699997  49.000000
# 229   80.500000  32.799999
# 230   75.000000  48.099998
# 231   75.500000  45.799999
# 232   75.400002  26.400000
# 233   76.900002  33.799999
# 234   78.500000  49.599998
# 235   85.000000  52.500000
# 236   73.699997  29.299999
# 237   74.099998  56.099998
# 238   75.300003  47.099998
# 239   72.300003  32.000000
# 240   76.599998   5.800000
# 241   84.000000  58.299999
# 242   85.500000  53.000000
# 243   78.300003  48.000000
# 244   81.599998  49.900002
# 245   74.400002  53.099998
# 246   77.800003  39.400002
# 247   72.400002  17.000000
# 248   74.199997  49.599998
# 249   75.199997  56.099998
# 250   78.300003  15.700000
# 251   72.300003  15.400000
# 252   81.900002  10.300000
# 253   82.000000  17.299999
# 254   73.500000  11.100000
# 255   78.000000  39.000000
# 256   79.199997  57.099998
# 257   74.300003  15.500000
# 258   72.300003  11.000000
# 259   88.000000   7.800000
# 260   76.300003  13.100000
# 261   73.099998   8.600000
# 262   84.000000  53.599998
# 263   99.000000  54.000000
# 264   81.500000  16.700001
# 265   76.000000   6.100000
# 266   72.800003   9.800000

# %% [markdown]
# ### Wechsel auf Analyse nach Wochentag

# %%
query ='''
SELECT  strftime('%w', time, 'localtime') as Weekday, strftime('%Y', time, 'localtime') as Year, strftime('%m', time, 'localtime') as Month, strftime('%d', time, 'localtime') as Day, COUNT(time) as Anzahl,
       ROUND(AVG(vfr11), 1) AS MEAN_Flow,
       MAX(vfr11) AS MAX_FLOW,
       MIN(vfr11) AS MIN_FLOW,
       ROUND(AVG(s12), 1) AS MEAN_Speed,
       MAX(s12) AS MAX_Speed,
       MIN(s12) AS MIN_Speed   
FROM tcdata_CH_0084_01
WHERE vfr11 > 0
GROUP BY strftime('%w', time, 'localtime') 
 '''

# %%
df = pd.read_sql_query(query, conn)

# %%
df.head(10)
# Out:
#   Weekday  Year Month Day  Anzahl  MEAN_Flow  MAX_FLOW  MIN_FLOW  MEAN_Speed  \
# 0       0  2021    11  21    9166     1061.8    3000.0      60.0        71.0
# 1       1  2021    11  29    9395     1392.2    2880.0      60.0        67.3
# 2       2  2022    03  15    9113     1393.2    2940.0      60.0        67.2
# 3       3  2021    12  08    9330     1417.9    2940.0      60.0        66.4
# 4       4  2022    02  03    9356     1429.0    2880.0      60.0        65.7
# 5       5  2022    02  18    9339     1461.1    2820.0      60.0        64.8
# 6       6  2021    11  20   10237     1340.6    2700.0      60.0        69.5
#
#    MAX_Speed  MIN_Speed
# 0      133.0       19.0
# 1      104.5        3.6
# 2      105.0        6.1
# 3      106.0       -1.0
# 4      105.0        5.0
# 5      102.0        5.8
# 6      117.0       21.9

# %%
query ='''
SELECT  strftime('%H', time, 'localtime') as Hour, strftime('%Y', time, 'localtime') as Year, strftime('%m', time, 'localtime') as Month, strftime('%d', time, 'localtime') as Day, COUNT(time) as Anzahl,
       ROUND(AVG(vfr11), 1) AS MEAN_Flow,
       MAX(vfr11) AS MAX_FLOW,
       MIN(vfr11) AS MIN_FLOW,
       ROUND(AVG(s12), 1) AS MEAN_Speed,
       MAX(s12) AS MAX_Speed,
       MIN(s12) AS MIN_Speed   
FROM tcdata_CH_0084_01
WHERE vfr11 > 0
GROUP BY strftime('%H', time, 'localtime') 
 '''

# %%
df = pd.read_sql_query(query, conn)

# %%
df.head(24)
# Out:
#    Hour  Year Month Day  Anzahl  MEAN_Flow  MAX_FLOW  MIN_FLOW  MEAN_Speed  \
# 0    00  2021    07  23     459      294.8     960.0      60.0        75.3
# 1    01  2021    07  27     421      191.8     840.0      60.0        75.4
# 2    02  2021    07  28     360      148.7     540.0      60.0        74.7
# 3    03  2021    07  30     390      139.4     540.0      60.0        74.8
# 4    04  2021    07  28     563      218.4     660.0      60.0        74.7
# 5    05  2021    11  29    2197      487.7    1560.0      60.0        71.2
# 6    06  2021    11  29    4831     1244.8    2940.0      60.0        69.6
# 7    07  2022    01  19    4916     1430.1    2940.0      60.0        66.6
# 8    08  2021    12  08    5047     1214.0    2340.0      60.0        68.8
# 9    09  2021    12  08    5086     1252.1    2280.0      60.0        68.8
# 10   10  2021    12  10    5062     1357.9    2460.0     180.0        68.1
# 11   11  2021    10  27    5031     1447.8    2640.0     480.0        68.0
# 12   12  2021    12  08    5092     1449.2    2640.0     540.0        68.6
# 13   13  2021    12  17    5035     1569.2    2700.0     600.0        67.4
# 14   14  2021    12  17    5046     1541.1    2640.0      60.0        67.3
# 15   15  2021    10  25    5093     1552.5    2700.0     240.0        67.4
# 16   16  2022    02  03    5047     1726.3    3000.0      60.0        62.1
# 17   17  2021    09  03    3684     1686.3    2880.0     120.0        56.6
# 18   18  2021    09  23     521     1579.6    2340.0     720.0        60.7
# 19   19  2021    08  03     158     1103.2    1980.0     120.0        71.7
# 20   20  2021    08  03     516      926.0    1680.0     180.0        74.4
# 21   21  2021    08  03     502      798.0    1560.0     180.0        74.2
# 22   22  2021    07  17     425      677.2    1440.0     120.0        74.5
# 23   23  2021    07  24     454      460.4    1440.0      60.0        75.2
#
#      MAX_Speed  MIN_Speed
# 0    99.500000  39.000000
# 1   105.000000  39.000000
# 2   101.000000  22.000000
# 3   102.000000  33.000000
# 4   106.000000  43.000000
# 5   133.000000  37.900002
# 6   102.500000   4.300000
# 7    97.000000   3.000000
# 8    87.500000  -1.000000
# 9    88.400002   4.300000
# 10   84.400002   6.400000
# 11   81.199997  28.000000
# 12   82.800003  30.200001
# 13   83.300003   9.100000
# 14   84.500000   7.900000
# 15   84.900002  18.400000
# 16   83.400002   5.000000
# 17   85.800003   6.800000
# 18   82.199997  16.200001
# 19   82.900002  53.200001
# 20   88.199997  60.900002
# 21   87.800003  58.400002
# 22   92.800003  58.099998
# 23  104.500000  52.200001
